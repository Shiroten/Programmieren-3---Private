# %%
import numpy as np
import math
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
import math
import time
import struct


modulus = math.pow(2,31)-1
multiplier = 1103515245
increment = 12345
seed = time.time()
random_value = seed
random_list = []


def own_random():
    global random_value
    random_value = (multiplier * random_value + increment) % modulus
    random_int = (int)(random_value)
    random_byte = random_int.to_bytes(4, byteorder='big', signed=True) 
    random_byte = random_byte[::-1]
    return_value = int.from_bytes(random_byte, byteorder='little')
    return_value = return_value / modulus
    return return_value

for _ in range (2000):
    print_value1 = own_random() 
    print_value2 = own_random()
    #print("{0:b}".format(print_value))
    #print(print_value)
    random_list.append((print_value1 ,print_value2))
    
#plt.plot([x[0] for x in random_list], [x[1] for x in random_list])
plt.scatter([x[0] for x in random_list], [x[1] for x in random_list])

# %%
import math
import time
import struct


modulus = math.pow(2,31)-1
multiplier = 1103515245
increment = 12345
seed = time.time()
random_value = seed
random_list = []


def own_random():
    global random_value
    random_value = (multiplier * random_value + increment) % modulus
    return random_value

for _ in range (2000):
    print_value1 = own_random() / math.pow(2,31)
    print_value2 = own_random() / math.pow(2,31)
    #print("{0:b}".format(print_value))
    #print(print_value)
    random_list.append((print_value1 ,print_value2))
    
plt.scatter([x[0] for x in random_list], [x[1] for x in random_list])

# %%
plt.plot([x[0] for x in random_list], [x[1] for x in random_list])

# %%
import random
random_list = []

for _ in range (2000):
    print_value1 = random.random()
    print_value2 = random.random()
    random_list.append((print_value1 ,print_value2))
    
plt.scatter([x[0] for x in random_list], [x[1] for x in random_list])
